# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
from difflib import SequenceMatcher

# %%
df = pd.read_json("hf://datasets/UCSC-VLAA/MedReason/ours_quality_33000.jsonl", lines=True)

df['question_char_len'] = df['question'].apply(len)
df['answer_char_len'] = df['answer'].apply(len)

df['question_word_count'] = df['question'].apply(lambda x: len(x.split()))
df['answer_word_count'] = df['answer'].apply(lambda x: len(x.split()))

# %%
def view_sample_answers(dataset, num_rows=5):
    for i in range(num_rows):
        print(dataset.iloc[i]['answer'])
        print('*' * 50)

def view_sample_options(dataset, num_rows=5):
    for i in range(num_rows):
        print(dataset.iloc[i]['options'])
        print('*' * 50)

def view_sample_questions(dataset, num_rows=5):
    for i in range(num_rows):
        print(dataset.iloc[i]['question'])
        print('*' * 50)

# %% [markdown]
# # MedMCQA

# %%
medmcqa_qs = df[df['dataset_name'] == 'medmcqa'].copy()
medmcqa_qs
# Out:
#       dataset_name  id_in_dataset  \
# 0          medmcqa           7131
# 1          medmcqa           7133
# 2          medmcqa           7134
# 3          medmcqa           7137
# 4          medmcqa           7138
# ...            ...            ...
# 29157      medmcqa           7125
# 29158      medmcqa           7126
# 29159      medmcqa           7128
# 29160      medmcqa           7129
# 29161      medmcqa           7130
#
#                                                 question  \
# 0      Urogenital Diaphragm is made up of the followi...
# 1      Child with Type I Diabetes. What is the advise...
# 2                   Most sensitive test for H pylori is-
# 3      Ligation of the common hepatic aery will compr...
# 4            Typhoid investigation of choice in 1st week
# ...                                                  ...
# 29157  A 60-year-old nursing home resident presents w...
# 29158                      Transcripton is inhibited by:
# 29159                                        Triage is –
# 29160  All of the following are true in respect of he...
# 29161  A 63-year-old bartender presents at his physic...
#
#                                                   answer  \
# 0      Colle's fascia. Explanation: Colle's fascia do...
# 1      After 5 years. Explanation: Screening for diab...
# 2      Biopsy urease test. Explanation: <P>Davidson&;...
# 3      Right gastric and right gastroepiploic aery. E...
# 4      Blood culture. Explanation: (A) Blood culture ...
# ...                                                  ...
# 29157  Contact precautions. Explanation: There are fo...
# 29158     Actinomycin D. Explanation: A i.e. Actinomycin
# 29159  Categorisation of the patients and treating th...
# 29160  Autosomal recessive disorder. Explanation: Her...
# 29161  Squamous cell carcinoma. Explanation: The tip ...
#
#                                                reasoning  \
# 0      Finding reasoning paths:\n1. Urogenital diaphr...
# 1      **Finding reasoning paths:**\n\n1. Type 1 Diab...
# 2      **Finding reasoning paths:**\n\n1. Consider th...
# 3      **Finding reasoning paths:**\n\n1. Common hepa...
# 4      Finding reasoning paths:\n\n1. Consider the pa...
# ...                                                  ...
# 29157  ### Finding Reasoning Paths:\n1. **Clinical Pr...
# 29158  ### Finding Reasoning Paths:\n1. mRNA transcri...
# 29159  ### Finding Reasoning Paths:\n1. **Severity of...
# 29160  ### Finding Reasoning Paths:\n1. **Complement ...
# 29161  ### Finding Reasoning Paths:\n1. The ulcerated...
#
#                                                  options  question_char_len  \
# 0      Answer Choices:\nA. Deep transverse Perineus\n...                 57
# 1      Answer Choices:\nA. After 5 years\nB. After 2 ...                104
# 2      Answer Choices:\nA. Fecal antigen test\nB. Bio...                 36
# 3      Answer Choices:\nA. Right and Left gastric aer...                 65
# 4      Answer Choices:\nA. Blood culture\nB. Widal te...                 43
# ...                                                  ...                ...
# 29157  Answer Choices:\nA. Standard precautions\nB. C...                340
# 29158  Answer Choices:\nA. Actinomycin D\nB. Amanitin...                 29
# 29159  Answer Choices:\nA. Treating the most serious ...                 11
# 29160  Answer Choices:\nA. Deficiency of C1 inhibitor...                 89
# 29161  Answer Choices:\nA. Lymphoma\nB. Squamous cell...                272
#
#        answer_char_len  question_word_count  answer_word_count
# 0                  343                    9                 54
# 1                  592                   18                 96
# 2                  178                    7                 21
# 3                  403                   11                 54
# 4                 1360                    7                239
# ...                ...                  ...                ...
# 29157             1610                   45                238
# 29158               46                    4                  6
# 29159              715                    3                103
# 29160              531                   14                 73
# 29161              173                   46                 27
#
# [6197 rows x 10 columns]

# %%
def count_answer_choices(text):
    if pd.isnull(text):
        return 0
    lines = text.strip().split('\n')
    choice_lines = lines[1:]
    count = sum(bool(re.match(r'^[A-Z]\.', line.strip())) for line in choice_lines)
    return count

medmcqa_qs['num_choices'] = medmcqa_qs['options'].apply(count_answer_choices)

# %%
def clean_text(text):
    """Lowercase, remove newlines/tabs/extra spaces, strip, remove trailing period."""
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)  # replace all whitespace (including \n, \t) with single space
    text = text.strip()
    text = text.rstrip('.')
    return text

def extract_mcq_label_fuzzy(answer_text, options_text, threshold=0.9):
    """
    Extracts MCQ letter (A-D) corresponding to the correct answer using fuzzy matching.
    Only uses cleaned text for matching; original text remains unchanged.
    """
    # Clean main answer (before Explanation:)
    answer_main = clean_text(answer_text.split("Explanation:")[0])

    # Extract options
    matches = re.findall(r'([A-D])\.\s*(.*)', options_text)

    best_letter = None
    best_ratio = 0

    for letter, text in matches:
        option_text = clean_text(text)
        ratio = SequenceMatcher(None, answer_main, option_text).ratio()
        if ratio > best_ratio and ratio >= threshold:
            best_ratio = ratio
            best_letter = letter

    return best_letter

# %%
medmcqa_qs['answer_label'] = medmcqa_qs.apply(lambda row: extract_mcq_label_fuzzy(row['answer'], row['options']), axis=1)

medmcqa_qs['answer_label'].value_counts(dropna=False)
# Out:
# answer_label
# A    1921
# B    1554
# C    1528
# D    1194
# Name: count, dtype: int64

# %%
medmcqa_qs["question_type"] = "MCQ"
medmcqa_qs
# Out:
#       dataset_name  id_in_dataset  \
# 0          medmcqa           7131
# 1          medmcqa           7133
# 2          medmcqa           7134
# 3          medmcqa           7137
# 4          medmcqa           7138
# ...            ...            ...
# 29157      medmcqa           7125
# 29158      medmcqa           7126
# 29159      medmcqa           7128
# 29160      medmcqa           7129
# 29161      medmcqa           7130
#
#                                                 question  \
# 0      Urogenital Diaphragm is made up of the followi...
# 1      Child with Type I Diabetes. What is the advise...
# 2                   Most sensitive test for H pylori is-
# 3      Ligation of the common hepatic aery will compr...
# 4            Typhoid investigation of choice in 1st week
# ...                                                  ...
# 29157  A 60-year-old nursing home resident presents w...
# 29158                      Transcripton is inhibited by:
# 29159                                        Triage is –
# 29160  All of the following are true in respect of he...
# 29161  A 63-year-old bartender presents at his physic...
#
#                                                   answer  \
# 0      Colle's fascia. Explanation: Colle's fascia do...
# 1      After 5 years. Explanation: Screening for diab...
# 2      Biopsy urease test. Explanation: <P>Davidson&;...
# 3      Right gastric and right gastroepiploic aery. E...
# 4      Blood culture. Explanation: (A) Blood culture ...
# ...                                                  ...
# 29157  Contact precautions. Explanation: There are fo...
# 29158     Actinomycin D. Explanation: A i.e. Actinomycin
# 29159  Categorisation of the patients and treating th...
# 29160  Autosomal recessive disorder. Explanation: Her...
# 29161  Squamous cell carcinoma. Explanation: The tip ...
#
#                                                reasoning  \
# 0      Finding reasoning paths:\n1. Urogenital diaphr...
# 1      **Finding reasoning paths:**\n\n1. Type 1 Diab...
# 2      **Finding reasoning paths:**\n\n1. Consider th...
# 3      **Finding reasoning paths:**\n\n1. Common hepa...
# 4      Finding reasoning paths:\n\n1. Consider the pa...
# ...                                                  ...
# 29157  ### Finding Reasoning Paths:\n1. **Clinical Pr...
# 29158  ### Finding Reasoning Paths:\n1. mRNA transcri...
# 29159  ### Finding Reasoning Paths:\n1. **Severity of...
# 29160  ### Finding Reasoning Paths:\n1. **Complement ...
# 29161  ### Finding Reasoning Paths:\n1. The ulcerated...
#
#                                                  options  question_char_len  \
# 0      Answer Choices:\nA. Deep transverse Perineus\n...                 57
# 1      Answer Choices:\nA. After 5 years\nB. After 2 ...                104
# 2      Answer Choices:\nA. Fecal antigen test\nB. Bio...                 36
# 3      Answer Choices:\nA. Right and Left gastric aer...                 65
# 4      Answer Choices:\nA. Blood culture\nB. Widal te...                 43
# ...                                                  ...                ...
# 29157  Answer Choices:\nA. Standard precautions\nB. C...                340
# 29158  Answer Choices:\nA. Actinomycin D\nB. Amanitin...                 29
# 29159  Answer Choices:\nA. Treating the most serious ...                 11
# 29160  Answer Choices:\nA. Deficiency of C1 inhibitor...                 89
# 29161  Answer Choices:\nA. Lymphoma\nB. Squamous cell...                272
#
#        answer_char_len  question_word_count  answer_word_count  num_choices  \
# 0                  343                    9                 54            4
# 1                  592                   18                 96            4
# 2                  178                    7                 21            4
# 3                  403                   11                 54            4
# 4                 1360                    7                239            4
# ...                ...                  ...                ...          ...
# 29157             1610                   45                238            4
# 29158               46                    4                  6            4
# 29159              715                    3                103            4
# 29160              531                   14                 73            4
# 29161              173                   46                 27            4
#
#       answer_label question_type
# 0                C           MCQ
# 1                A           MCQ
# 2                B           MCQ
# 3                D           MCQ
# 4                A           MCQ
# ...            ...           ...
# 29157            B           MCQ
# 29158            A           MCQ
# 29159            B           MCQ
# 29160            D           MCQ
# 29161            B           MCQ
#
# [6197 rows x 13 columns]

# %% [markdown]
# # PubMedQA

# %%
pubmedqa_qs = df[df['dataset_name'] == "pubmedqa"].copy()
pubmedqa_qs
# Out:
#       dataset_name  id_in_dataset  \
# 13055     pubmedqa              0
# 13056     pubmedqa              1
# 13057     pubmedqa              4
# 13058     pubmedqa              9
# 13059     pubmedqa             11
# ...            ...            ...
# 13653     pubmedqa            993
# 13654     pubmedqa            994
# 13655     pubmedqa            995
# 13656     pubmedqa            997
# 13657     pubmedqa            998
#
#                                                 question  \
# 13055  Do mitochondria play a role in remodelling lac...
# 13056  Landolt C and snellen e acuity: differences in...
# 13057  Can tailored interventions increase mammograph...
# 13058  A short stay or 23-hour ward in a general and ...
# 13059  Therapeutic anticoagulation in the trauma pati...
# ...                                                  ...
# 13653  Are many colorectal cancers due to missed aden...
# 13654  Does desflurane alter left ventricular functio...
# 13655  Does gestational age misclassification explain...
# 13656  Is peak concentration needed in therapeutic dr...
# 13657  Can autologous platelet-rich plasma gel enhanc...
#
#                                                   answer  \
# 13055  The final decision is: yes. Results depicted m...
# 13056  The final decision is: no. Using the charts de...
# 13057  The final decision is: yes. The effects of the...
# 13058  The final decision is: yes. This data demonstr...
# 13059  The final decision is: no. Trauma patients hav...
# ...                                                  ...
# 13653  The final decision is: no. In normal daily pra...
# 13654  The final decision is: no. This study demonstr...
# 13655  The final decision is: no. Gestational age mis...
# 13656  The final decision is: no. These results sugge...
# 13657  The final decision is: yes. The PRP group reco...
#
#                                                reasoning  \
# 13055  ### Finding Reasoning Paths:\n1. Mitochondria ...
# 13056  ### Finding Reasoning Paths:\n1. Strabismus ->...
# 13057  ### Finding Reasoning Paths:\n1. **Effectivene...
# 13058  ### Finding Reasoning Paths:\n1. **Bed Efficie...
# 13059  ### Finding Reasoning Paths:\n1. **Response to...
# ...                                                  ...
# 13653  ### Finding Reasoning Paths:\n1. Colorectal ca...
# 13654  ### Finding Reasoning Paths:\n1. Desflurane's ...
# 13655  ### Finding Reasoning Paths:\n1. Investigate w...
# 13656  ### Finding Reasoning Paths:\n1. Vancomycin ->...
# 13657  ### Finding Reasoning Paths:\n1. **Path 1**: P...
#
#                               options  question_char_len  answer_char_len  \
# 13055  Answer Choices:\nA. Yes\nB. No                 90              645
# 13056  Answer Choices:\nA. Yes\nB. No                 68              258
# 13057  Answer Choices:\nA. Yes\nB. No                 68              816
# 13058  Answer Choices:\nA. Yes\nB. No                 95              333
# 13059  Answer Choices:\nA. Yes\nB. No                 62              333
# ...                               ...                ...              ...
# 13653  Answer Choices:\nA. Yes\nB. No                 51              179
# 13654  Answer Choices:\nA. Yes\nB. No                112              238
# 13655  Answer Choices:\nA. Yes\nB. No                115              255
# 13656  Answer Choices:\nA. Yes\nB. No                 74              195
# 13657  Answer Choices:\nA. Yes\nB. No                109              304
#
#        question_word_count  answer_word_count
# 13055                   14                102
# 13056                   10                 43
# 13057                    9                110
# 13058                   16                 55
# 13059                    9                 46
# ...                    ...                ...
# 13653                    8                 28
# 13654                   15                 33
# 13655                   14                 34
# 13656                   10                 31
# 13657                   14                 50
#
# [603 rows x 10 columns]

# %%
def extract_decision(text):
    # Regex to find "yes" or "no" after "The final decision is:"
    match = re.search(r"The final decision is:\s*(yes|no|maybe)", text, flags=re.IGNORECASE)
    if match:
        return match.group(1).lower()   # return 'yes' or 'no'
    return None

# Apply to your dataframe
pubmedqa_qs['answer_label'] = pubmedqa_qs['answer'].apply(extract_decision)

# Count distribution
print(pubmedqa_qs['answer_label'].value_counts())
# Out:
# answer_label
# yes      421
# no       181
# maybe      1
# Name: count, dtype: int64

# %%
# Remove row with answer_label 'maybe'
pubmedqa_qs = pubmedqa_qs[pubmedqa_qs['answer_label'] != 'maybe']
pubmedqa_qs[['question', 'answer', 'answer_label']]
# Out:
#                                                 question  \
# 13055  Do mitochondria play a role in remodelling lac...
# 13056  Landolt C and snellen e acuity: differences in...
# 13057  Can tailored interventions increase mammograph...
# 13058  A short stay or 23-hour ward in a general and ...
# 13059  Therapeutic anticoagulation in the trauma pati...
# ...                                                  ...
# 13653  Are many colorectal cancers due to missed aden...
# 13654  Does desflurane alter left ventricular functio...
# 13655  Does gestational age misclassification explain...
# 13656  Is peak concentration needed in therapeutic dr...
# 13657  Can autologous platelet-rich plasma gel enhanc...
#
#                                                   answer answer_label
# 13055  The final decision is: yes. Results depicted m...          yes
# 13056  The final decision is: no. Using the charts de...           no
# 13057  The final decision is: yes. The effects of the...          yes
# 13058  The final decision is: yes. This data demonstr...          yes
# 13059  The final decision is: no. Trauma patients hav...           no
# ...                                                  ...          ...
# 13653  The final decision is: no. In normal daily pra...           no
# 13654  The final decision is: no. This study demonstr...           no
# 13655  The final decision is: no. Gestational age mis...           no
# 13656  The final decision is: no. These results sugge...           no
# 13657  The final decision is: yes. The PRP group reco...          yes
#
# [602 rows x 3 columns]

# %%
pubmedqa_qs["question_type"] = "Y/N"
pubmedqa_qs
# Out:
# /tmp/ipython-input-2260965923.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pubmedqa_qs["question_type"] = "Y/N"
#       dataset_name  id_in_dataset  \
# 13055     pubmedqa              0
# 13056     pubmedqa              1
# 13057     pubmedqa              4
# 13058     pubmedqa              9
# 13059     pubmedqa             11
# ...            ...            ...
# 13653     pubmedqa            993
# 13654     pubmedqa            994
# 13655     pubmedqa            995
# 13656     pubmedqa            997
# 13657     pubmedqa            998
#
#                                                 question  \
# 13055  Do mitochondria play a role in remodelling lac...
# 13056  Landolt C and snellen e acuity: differences in...
# 13057  Can tailored interventions increase mammograph...
# 13058  A short stay or 23-hour ward in a general and ...
# 13059  Therapeutic anticoagulation in the trauma pati...
# ...                                                  ...
# 13653  Are many colorectal cancers due to missed aden...
# 13654  Does desflurane alter left ventricular functio...
# 13655  Does gestational age misclassification explain...
# 13656  Is peak concentration needed in therapeutic dr...
# 13657  Can autologous platelet-rich plasma gel enhanc...
#
#                                                   answer  \
# 13055  The final decision is: yes. Results depicted m...
# 13056  The final decision is: no. Using the charts de...
# 13057  The final decision is: yes. The effects of the...
# 13058  The final decision is: yes. This data demonstr...
# 13059  The final decision is: no. Trauma patients hav...
# ...                                                  ...
# 13653  The final decision is: no. In normal daily pra...
# 13654  The final decision is: no. This study demonstr...
# 13655  The final decision is: no. Gestational age mis...
# 13656  The final decision is: no. These results sugge...
# 13657  The final decision is: yes. The PRP group reco...
#
#                                                reasoning  \
# 13055  ### Finding Reasoning Paths:\n1. Mitochondria ...
# 13056  ### Finding Reasoning Paths:\n1. Strabismus ->...
# 13057  ### Finding Reasoning Paths:\n1. **Effectivene...
# 13058  ### Finding Reasoning Paths:\n1. **Bed Efficie...
# 13059  ### Finding Reasoning Paths:\n1. **Response to...
# ...                                                  ...
# 13653  ### Finding Reasoning Paths:\n1. Colorectal ca...
# 13654  ### Finding Reasoning Paths:\n1. Desflurane's ...
# 13655  ### Finding Reasoning Paths:\n1. Investigate w...
# 13656  ### Finding Reasoning Paths:\n1. Vancomycin ->...
# 13657  ### Finding Reasoning Paths:\n1. **Path 1**: P...
#
#                               options  question_char_len  answer_char_len  \
# 13055  Answer Choices:\nA. Yes\nB. No                 90              645
# 13056  Answer Choices:\nA. Yes\nB. No                 68              258
# 13057  Answer Choices:\nA. Yes\nB. No                 68              816
# 13058  Answer Choices:\nA. Yes\nB. No                 95              333
# 13059  Answer Choices:\nA. Yes\nB. No                 62              333
# ...                               ...                ...              ...
# 13653  Answer Choices:\nA. Yes\nB. No                 51              179
# 13654  Answer Choices:\nA. Yes\nB. No                112              238
# 13655  Answer Choices:\nA. Yes\nB. No                115              255
# 13656  Answer Choices:\nA. Yes\nB. No                 74              195
# 13657  Answer Choices:\nA. Yes\nB. No                109              304
#
#        question_word_count  answer_word_count answer_label question_type
# 13055                   14                102          yes           Y/N
# 13056                   10                 43           no           Y/N
# 13057                    9                110          yes           Y/N
# 13058                   16                 55          yes           Y/N
# 13059                    9                 46           no           Y/N
# ...                    ...                ...          ...           ...
# 13653                    8                 28           no           Y/N
# 13654                   15                 33           no           Y/N
# 13655                   14                 34           no           Y/N
# 13656                   10                 31           no           Y/N
# 13657                   14                 50          yes           Y/N
#
# [602 rows x 12 columns]

# %% [markdown]
# # medqa

# %%
medqa_qs = df[df['dataset_name'] == "medqa"].copy()
medqa_qs
# Out:
#       dataset_name  id_in_dataset  \
# 2011         medqa           7595
# 2012         medqa           7596
# 2013         medqa           7598
# 2014         medqa           7599
# 2015         medqa           7600
# ...            ...            ...
# 32677        medqa            995
# 32678        medqa            996
# 32679        medqa            997
# 32680        medqa            998
# 32681        medqa            999
#
#                                                 question  \
# 2011   A 62-year-old man presents with multiple episo...
# 2012   An 84-year-old man is brought to the physician...
# 2013   A 44-year-old man, with a history of intraveno...
# 2014   A 33-year-old woman comes to the physician bec...
# 2015   A 23-year-old man is brought to the emergency ...
# ...                                                  ...
# 32677  A 51-year-old man is bitten by a cottonmouth v...
# 32678  A 47-year-old man presents to the clinic for a...
# 32679  A 24-year-old woman presents to her primary ca...
# 32680  A 70-year-old man presents with fever, headach...
# 32681  A 15-year-old girl presents to her primary car...
#
#                                          answer  \
# 2011           Small cell carcinoma of the lung
# 2012    Denudation of tubular basement membrane
# 2013              Trimethoprim-sulfamethoxazole
# 2014                          Optic neuritis\n"
# 2015                  Schizophreniform disorder
# ...                                         ...
# 32677  Glucocorticoid taper with antihistamines
# 32678                              Bed bug bite
# 32679        Motile and helical-shaped bacteria
# 32680                                Ampicillin
# 32681                               Hypokalemia
#
#                                                reasoning  \
# 2011   **Finding reasoning paths:**\n\n1. Hemoptysis ...
# 2012   **Finding reasoning paths:**\n\n1. Decreased u...
# 2013   Finding reasoning paths:\n1. Non-productive co...
# 2014   **Finding reasoning paths:**\n\n1. Visual impa...
# 2015   Finding reasoning paths:\n1. Behavioral abnorm...
# ...                                                  ...
# 32677  ### Finding Reasoning Paths:\n1. **Pruritis an...
# 32678  ### Finding Reasoning Paths:\n1. **Pruritus an...
# 32679  ### Finding Reasoning Paths:\n1. The patient h...
# 32680  ### Finding Reasoning Paths:\n1. Fever, headac...
# 32681  ### Finding Reasoning Paths:\n1. Chronic const...
#
#                                                  options  question_char_len  \
# 2011   Answer Choices:\nA. Tuberculoma\nB. Small cell...                553
# 2012   Answer Choices:\nA. Leukocytic infiltration of...                582
# 2013   Answer Choices:\nA. Isoniazid, rifabutin, pyra...               1123
# 2014   Answer Choices:\nA. Retinal detachment\nB. Nar...                963
# 2015   Answer Choices:\nA. Schizoaffective disorder\n...                791
# ...                                                  ...                ...
# 32677  Answer Choices:\nA. Glucocorticoid taper with ...               1009
# 32678  Answer Choices:\nA. Cutaneous larva migrans\nB...                750
# 32679  Answer Choices:\nA. Gram-negative coccobacillu...                812
# 32680  Answer Choices:\nA. Ampicillin\nB. Ceftriaxone...                808
# 32681  Answer Choices:\nA. Hypocalcemia\nB. Hypokalem...                805
#
#        answer_char_len  question_word_count  answer_word_count
# 2011                32                   94                  6
# 2012                39                   99                  5
# 2013                29                  175                  1
# 2014                16                  165                  3
# 2015                25                  130                  2
# ...                ...                  ...                ...
# 32677               40                  156                  4
# 32678               12                  128                  3
# 32679               34                  134                  4
# 32680               10                  120                  1
# 32681               11                  129                  1
#
# [8016 rows x 10 columns]

# %%
medqa_qs['num_choices'] = medqa_qs['options'].apply(count_answer_choices)

print(medqa_qs['num_choices'].value_counts())
# Out:
# num_choices
# 4    8016
# Name: count, dtype: int64

# %%
def extract_mcq_label_fuzzy(answer_text, options_text, threshold=0.9):
    """
    Extracts MCQ letter (A-D) corresponding to the correct answer using fuzzy matching.
    Only uses cleaned text for matching; original text remains unchanged.
    """
    answer_main = clean_text(answer_text)

    # Extract options
    matches = re.findall(r'([A-D])\.\s*(.*)', options_text)

    best_letter = None
    best_ratio = 0

    for letter, text in matches:
        option_text = clean_text(text)
        ratio = SequenceMatcher(None, answer_main, option_text).ratio()
        if ratio > best_ratio and ratio >= threshold:
            best_ratio = ratio
            best_letter = letter

    return best_letter

# %%
medqa_qs['answer_label'] = medqa_qs.apply(lambda row: extract_mcq_label_fuzzy(row['answer'], row['options'], 0.80), axis=1)
medqa_qs['answer_label'].value_counts(dropna=False)
# Out:
# answer_label
# B    2074
# A    2055
# C    2028
# D    1859
# Name: count, dtype: int64

# %%
medqa_qs['answer_label'].value_counts(dropna=False).sum()
# Out:
# np.int64(8016)

# %%
medqa_qs["question_type"] = "MCQ"
medqa_qs
# Out:
#       dataset_name  id_in_dataset  \
# 2011         medqa           7595
# 2012         medqa           7596
# 2013         medqa           7598
# 2014         medqa           7599
# 2015         medqa           7600
# ...            ...            ...
# 32677        medqa            995
# 32678        medqa            996
# 32679        medqa            997
# 32680        medqa            998
# 32681        medqa            999
#
#                                                 question  \
# 2011   A 62-year-old man presents with multiple episo...
# 2012   An 84-year-old man is brought to the physician...
# 2013   A 44-year-old man, with a history of intraveno...
# 2014   A 33-year-old woman comes to the physician bec...
# 2015   A 23-year-old man is brought to the emergency ...
# ...                                                  ...
# 32677  A 51-year-old man is bitten by a cottonmouth v...
# 32678  A 47-year-old man presents to the clinic for a...
# 32679  A 24-year-old woman presents to her primary ca...
# 32680  A 70-year-old man presents with fever, headach...
# 32681  A 15-year-old girl presents to her primary car...
#
#                                          answer  \
# 2011           Small cell carcinoma of the lung
# 2012    Denudation of tubular basement membrane
# 2013              Trimethoprim-sulfamethoxazole
# 2014                          Optic neuritis\n"
# 2015                  Schizophreniform disorder
# ...                                         ...
# 32677  Glucocorticoid taper with antihistamines
# 32678                              Bed bug bite
# 32679        Motile and helical-shaped bacteria
# 32680                                Ampicillin
# 32681                               Hypokalemia
#
#                                                reasoning  \
# 2011   **Finding reasoning paths:**\n\n1. Hemoptysis ...
# 2012   **Finding reasoning paths:**\n\n1. Decreased u...
# 2013   Finding reasoning paths:\n1. Non-productive co...
# 2014   **Finding reasoning paths:**\n\n1. Visual impa...
# 2015   Finding reasoning paths:\n1. Behavioral abnorm...
# ...                                                  ...
# 32677  ### Finding Reasoning Paths:\n1. **Pruritis an...
# 32678  ### Finding Reasoning Paths:\n1. **Pruritus an...
# 32679  ### Finding Reasoning Paths:\n1. The patient h...
# 32680  ### Finding Reasoning Paths:\n1. Fever, headac...
# 32681  ### Finding Reasoning Paths:\n1. Chronic const...
#
#                                                  options  question_char_len  \
# 2011   Answer Choices:\nA. Tuberculoma\nB. Small cell...                553
# 2012   Answer Choices:\nA. Leukocytic infiltration of...                582
# 2013   Answer Choices:\nA. Isoniazid, rifabutin, pyra...               1123
# 2014   Answer Choices:\nA. Retinal detachment\nB. Nar...                963
# 2015   Answer Choices:\nA. Schizoaffective disorder\n...                791
# ...                                                  ...                ...
# 32677  Answer Choices:\nA. Glucocorticoid taper with ...               1009
# 32678  Answer Choices:\nA. Cutaneous larva migrans\nB...                750
# 32679  Answer Choices:\nA. Gram-negative coccobacillu...                812
# 32680  Answer Choices:\nA. Ampicillin\nB. Ceftriaxone...                808
# 32681  Answer Choices:\nA. Hypocalcemia\nB. Hypokalem...                805
#
#        answer_char_len  question_word_count  answer_word_count  num_choices  \
# 2011                32                   94                  6            4
# 2012                39                   99                  5            4
# 2013                29                  175                  1            4
# 2014                16                  165                  3            4
# 2015                25                  130                  2            4
# ...                ...                  ...                ...          ...
# 32677               40                  156                  4            4
# 32678               12                  128                  3            4
# 32679               34                  134                  4            4
# 32680               10                  120                  1            4
# 32681               11                  129                  1            4
#
#       answer_label question_type
# 2011             B           MCQ
# 2012             C           MCQ
# 2013             D           MCQ
# 2014             D           MCQ
# 2015             C           MCQ
# ...            ...           ...
# 32677            A           MCQ
# 32678            B           MCQ
# 32679            C           MCQ
# 32680            A           MCQ
# 32681            B           MCQ
#
# [8016 rows x 13 columns]

# %% [markdown]
# # MMLU

# %%
MMLU_qs = df[df['dataset_name'] == "MMLU"].copy()
MMLU_qs
# Out:
#       dataset_name  id_in_dataset  \
# 12749         MMLU           1000
# 12750         MMLU           1001
# 12751         MMLU           1002
# 12752         MMLU           1004
# 12753         MMLU           1005
# ...            ...            ...
# 24974         MMLU            995
# 24975         MMLU            996
# 24976         MMLU            997
# 24977         MMLU            998
# 24978         MMLU            999
#
#                                                 question  \
# 12749  A 22-year-old woman comes to the office becaus...
# 12750  A 53-year-old man comes to the physician becau...
# 12751  A study is being conducted to assess mesotheli...
# 12752  A 31-year-old man with a 5-year history of HIV...
# 12753  A 71-year-old woman is brought to the emergenc...
# ...                                                  ...
# 24974  You are visiting an 86-year-old woman in her h...
# 24975  A 37-year-old woman comes to the physician bec...
# 24976  A 42-year-old woman is brought to the emergenc...
# 24977  A 19-year-old woman who is a regular patient c...
# 24978  A 44-year-old female presents to the office fo...
#
#                                                   answer  \
# 12749                                           BK virus
# 12750                               Superficial inguinal
# 12751                        Minimize ascertainment bias
# 12752                                          Imiquimod
# 12753                                  Vascular dementia
# ...                                                  ...
# 24974  Arrange for consultation with a home hospice team
# 24975                           Streptococcus pneumoniae
# 24976                                         Laparotomy
# 24977                        Polycystic ovarian syndrome
# 24978               ultrasonography of the thyroid gland
#
#                                                reasoning  \
# 12749  ### Finding Reasoning Paths:\n1. **Immunosuppr...
# 12750  ### Finding Reasoning Paths:\n1. Anal mass loc...
# 12751  ### Finding Reasoning Paths:\n1. Asbestos expo...
# 12752  ### Finding Reasoning Paths:\n1. **HIV infecti...
# 12753  ### Finding Reasoning Paths:\n1. **Hypertensio...
# ...                                                  ...
# 24974  ### Finding Reasoning Paths:\n1. Chronic obstr...
# 24975  ### Finding Reasoning Paths:\n1. **Purulent na...
# 24976  ### Finding Reasoning Paths:\n1. **Abnormal br...
# 24977  ### Finding Reasoning Paths:\n1. **Irregular m...
# 24978  ### Finding Reasoning Paths:\n1. **Thyroid nod...
#
#                                                  options  question_char_len  \
# 12749  Answer Choices:\nA. Adenovirus\nB. BK virus\nC...                695
# 12750  Answer Choices:\nA. Internal iliac\nB. Poplite...                394
# 12751  Answer Choices:\nA. Address confounding\nB. De...                624
# 12752  Answer Choices:\nA. Acyclovir\nB. Imiquimod\nC...               1244
# 12753  Answer Choices:\nA. Amyotrophic lateral sclero...               1394
# ...                                                  ...                ...
# 24974  Answer Choices:\nA. Admit the patient to the h...               1436
# 24975  Answer Choices:\nA. Haemophilus influenzae typ...                774
# 24976  Answer Choices:\nA. CT scan of the abdomen\nB....                629
# 24977  Answer Choices:\nA. Androgen-producing ovarian...               1151
# 24978  Answer Choices:\nA. a nuclear thyroid scan\nB....                397
#
#        answer_char_len  question_word_count  answer_word_count
# 12749                8                  100                  2
# 12750               20                   68                  2
# 12751               27                   99                  3
# 12752                9                  195                  1
# 12753               17                  235                  2
# ...                ...                  ...                ...
# 24974               49                  239                  8
# 24975               24                  126                  2
# 24976               10                  106                  1
# 24977               27                  199                  3
# 24978               36                   65                  5
#
# [827 rows x 10 columns]

# %%
MMLU_qs['num_choices'] = MMLU_qs['options'].apply(count_answer_choices)

print(MMLU_qs['num_choices'].value_counts())
# Out:
# num_choices
# 4    827
# Name: count, dtype: int64

# %%
MMLU_qs['answer_label'] = MMLU_qs.apply(lambda row: extract_mcq_label_fuzzy(row['answer'], row['options'], 0.9), axis=1)
MMLU_qs['answer_label'].value_counts(dropna=False)
# Out:
# answer_label
# D    257
# C    196
# B    190
# A    184
# Name: count, dtype: int64

# %%
MMLU_qs["question_type"] = "MCQ"
MMLU_qs
# Out:
#       dataset_name  id_in_dataset  \
# 12749         MMLU           1000
# 12750         MMLU           1001
# 12751         MMLU           1002
# 12752         MMLU           1004
# 12753         MMLU           1005
# ...            ...            ...
# 24974         MMLU            995
# 24975         MMLU            996
# 24976         MMLU            997
# 24977         MMLU            998
# 24978         MMLU            999
#
#                                                 question  \
# 12749  A 22-year-old woman comes to the office becaus...
# 12750  A 53-year-old man comes to the physician becau...
# 12751  A study is being conducted to assess mesotheli...
# 12752  A 31-year-old man with a 5-year history of HIV...
# 12753  A 71-year-old woman is brought to the emergenc...
# ...                                                  ...
# 24974  You are visiting an 86-year-old woman in her h...
# 24975  A 37-year-old woman comes to the physician bec...
# 24976  A 42-year-old woman is brought to the emergenc...
# 24977  A 19-year-old woman who is a regular patient c...
# 24978  A 44-year-old female presents to the office fo...
#
#                                                   answer  \
# 12749                                           BK virus
# 12750                               Superficial inguinal
# 12751                        Minimize ascertainment bias
# 12752                                          Imiquimod
# 12753                                  Vascular dementia
# ...                                                  ...
# 24974  Arrange for consultation with a home hospice team
# 24975                           Streptococcus pneumoniae
# 24976                                         Laparotomy
# 24977                        Polycystic ovarian syndrome
# 24978               ultrasonography of the thyroid gland
#
#                                                reasoning  \
# 12749  ### Finding Reasoning Paths:\n1. **Immunosuppr...
# 12750  ### Finding Reasoning Paths:\n1. Anal mass loc...
# 12751  ### Finding Reasoning Paths:\n1. Asbestos expo...
# 12752  ### Finding Reasoning Paths:\n1. **HIV infecti...
# 12753  ### Finding Reasoning Paths:\n1. **Hypertensio...
# ...                                                  ...
# 24974  ### Finding Reasoning Paths:\n1. Chronic obstr...
# 24975  ### Finding Reasoning Paths:\n1. **Purulent na...
# 24976  ### Finding Reasoning Paths:\n1. **Abnormal br...
# 24977  ### Finding Reasoning Paths:\n1. **Irregular m...
# 24978  ### Finding Reasoning Paths:\n1. **Thyroid nod...
#
#                                                  options  question_char_len  \
# 12749  Answer Choices:\nA. Adenovirus\nB. BK virus\nC...                695
# 12750  Answer Choices:\nA. Internal iliac\nB. Poplite...                394
# 12751  Answer Choices:\nA. Address confounding\nB. De...                624
# 12752  Answer Choices:\nA. Acyclovir\nB. Imiquimod\nC...               1244
# 12753  Answer Choices:\nA. Amyotrophic lateral sclero...               1394
# ...                                                  ...                ...
# 24974  Answer Choices:\nA. Admit the patient to the h...               1436
# 24975  Answer Choices:\nA. Haemophilus influenzae typ...                774
# 24976  Answer Choices:\nA. CT scan of the abdomen\nB....                629
# 24977  Answer Choices:\nA. Androgen-producing ovarian...               1151
# 24978  Answer Choices:\nA. a nuclear thyroid scan\nB....                397
#
#        answer_char_len  question_word_count  answer_word_count  num_choices  \
# 12749                8                  100                  2            4
# 12750               20                   68                  2            4
# 12751               27                   99                  3            4
# 12752                9                  195                  1            4
# 12753               17                  235                  2            4
# ...                ...                  ...                ...          ...
# 24974               49                  239                  8            4
# 24975               24                  126                  2            4
# 24976               10                  106                  1            4
# 24977               27                  199                  3            4
# 24978               36                   65                  5            4
#
#       answer_label question_type
# 12749            B           MCQ
# 12750            D           MCQ
# 12751            C           MCQ
# 12752            B           MCQ
# 12753            D           MCQ
# ...            ...           ...
# 24974            B           MCQ
# 24975            D           MCQ
# 24976            D           MCQ
# 24977            D           MCQ
# 24978            D           MCQ
#
# [827 rows x 13 columns]

# %% [markdown]
# # Compile

# %%
desired_cols = ["dataset_name", "id_in_dataset", "question", "options", "answer_label", "question_type"]

compiled_df = pd.concat([medmcqa_qs[desired_cols], pubmedqa_qs[desired_cols], medqa_qs[desired_cols], MMLU_qs[desired_cols]])
compiled_df
# Out:
#       dataset_name  id_in_dataset  \
# 0          medmcqa           7131
# 1          medmcqa           7133
# 2          medmcqa           7134
# 3          medmcqa           7137
# 4          medmcqa           7138
# ...            ...            ...
# 24974         MMLU            995
# 24975         MMLU            996
# 24976         MMLU            997
# 24977         MMLU            998
# 24978         MMLU            999
#
#                                                 question  \
# 0      Urogenital Diaphragm is made up of the followi...
# 1      Child with Type I Diabetes. What is the advise...
# 2                   Most sensitive test for H pylori is-
# 3      Ligation of the common hepatic aery will compr...
# 4            Typhoid investigation of choice in 1st week
# ...                                                  ...
# 24974  You are visiting an 86-year-old woman in her h...
# 24975  A 37-year-old woman comes to the physician bec...
# 24976  A 42-year-old woman is brought to the emergenc...
# 24977  A 19-year-old woman who is a regular patient c...
# 24978  A 44-year-old female presents to the office fo...
#
#                                                  options answer_label  \
# 0      Answer Choices:\nA. Deep transverse Perineus\n...            C
# 1      Answer Choices:\nA. After 5 years\nB. After 2 ...            A
# 2      Answer Choices:\nA. Fecal antigen test\nB. Bio...            B
# 3      Answer Choices:\nA. Right and Left gastric aer...            D
# 4      Answer Choices:\nA. Blood culture\nB. Widal te...            A
# ...                                                  ...          ...
# 24974  Answer Choices:\nA. Admit the patient to the h...            B
# 24975  Answer Choices:\nA. Haemophilus influenzae typ...            D
# 24976  Answer Choices:\nA. CT scan of the abdomen\nB....            D
# 24977  Answer Choices:\nA. Androgen-producing ovarian...            D
# 24978  Answer Choices:\nA. a nuclear thyroid scan\nB....            D
#
#       question_type
# 0               MCQ
# 1               MCQ
# 2               MCQ
# 3               MCQ
# 4               MCQ
# ...             ...
# 24974           MCQ
# 24975           MCQ
# 24976           MCQ
# 24977           MCQ
# 24978           MCQ
#
# [15642 rows x 6 columns]

# %%
# check nulls
compiled_df.isnull().sum()
# Out:
# dataset_name     0
# id_in_dataset    0
# question         0
# options          0
# answer_label     0
# question_type    0
# dtype: int64

# %%
# reset index
compiled_df = compiled_df.reset_index(drop=True)
compiled_df
# Out:
#       dataset_name  id_in_dataset  \
# 0          medmcqa           7131
# 1          medmcqa           7133
# 2          medmcqa           7134
# 3          medmcqa           7137
# 4          medmcqa           7138
# ...            ...            ...
# 15637         MMLU            995
# 15638         MMLU            996
# 15639         MMLU            997
# 15640         MMLU            998
# 15641         MMLU            999
#
#                                                 question  \
# 0      Urogenital Diaphragm is made up of the followi...
# 1      Child with Type I Diabetes. What is the advise...
# 2                   Most sensitive test for H pylori is-
# 3      Ligation of the common hepatic aery will compr...
# 4            Typhoid investigation of choice in 1st week
# ...                                                  ...
# 15637  You are visiting an 86-year-old woman in her h...
# 15638  A 37-year-old woman comes to the physician bec...
# 15639  A 42-year-old woman is brought to the emergenc...
# 15640  A 19-year-old woman who is a regular patient c...
# 15641  A 44-year-old female presents to the office fo...
#
#                                                  options answer_label  \
# 0      Answer Choices:\nA. Deep transverse Perineus\n...            C
# 1      Answer Choices:\nA. After 5 years\nB. After 2 ...            A
# 2      Answer Choices:\nA. Fecal antigen test\nB. Bio...            B
# 3      Answer Choices:\nA. Right and Left gastric aer...            D
# 4      Answer Choices:\nA. Blood culture\nB. Widal te...            A
# ...                                                  ...          ...
# 15637  Answer Choices:\nA. Admit the patient to the h...            B
# 15638  Answer Choices:\nA. Haemophilus influenzae typ...            D
# 15639  Answer Choices:\nA. CT scan of the abdomen\nB....            D
# 15640  Answer Choices:\nA. Androgen-producing ovarian...            D
# 15641  Answer Choices:\nA. a nuclear thyroid scan\nB....            D
#
#       question_type
# 0               MCQ
# 1               MCQ
# 2               MCQ
# 3               MCQ
# 4               MCQ
# ...             ...
# 15637           MCQ
# 15638           MCQ
# 15639           MCQ
# 15640           MCQ
# 15641           MCQ
#
# [15642 rows x 6 columns]

# %%
def make_prompt(row):
    q = str(row.get("question", "")).strip()
    opts = str(row.get("options", "")).strip()

    # Build final text: question first, then answer choices
    if opts and not pd.isnull(opts):
        return f"Question:\n{q}\n\n{opts}"
    else:
        return f"Question:\n{q}"


# Apply to dataframe
compiled_df["prompt_text"] = compiled_df.apply(make_prompt, axis=1)

# %%
for i in range(20):
    print(compiled_df.iloc[i]['prompt_text'])
    print('*' * 50)
# Out:
# Question:
# Urogenital Diaphragm is made up of the following, except:
#
# Answer Choices:
# A. Deep transverse Perineus
# B. Perinial membrane
# C. Colle's fascia
# D. Sphincter Urethrae
# **************************************************
# Question:
# Child with Type I Diabetes. What is the advised time for fundus examinations from the time of diagnosis?
#
# Answer Choices:
# A. After 5 years
# B. After 2 years
# C. After 10 years
# D. At the time of diagnosis
# **************************************************
# Question:
# Most sensitive test for H pylori is-
#
# Answer Choices:
# A. Fecal antigen test
# B. Biopsy urease test
# C. Serological test
# D. Urea breath test
# **************************************************
# Question:
# Ligation of the common hepatic aery will compromise blood flow in
#
# Answer Choices:
# A. Right and Left gastric aery
# B. Right gastric and sho gastric aeries
# C. Right gastroepiploic and sho gastric aeries
# D. Right gastric and right gastroepiploic aery
# **************************************************
# Question:
# Typhoid investigation of choice in 1st week
#
# Answer Choices:
# A. Blood culture
# B. Widal test
# C. Stool culture
# D. Urine culture
# **************************************************
# Question:
# Perforation of stomach is more common due to ingestion of -
#
# Answer Choices:
# A. Nitric acid
# B. Sulphuric acid
# C. Hydrochloric acid
# D. Carbolic acid
# **************************************************
# Question:
# Brown tumour is seen in
#
# Answer Choices:
# A. Hyperparathyroidism
# B. Hypoparathyroidism
# C. Hypothyroidism
# D. Hypehyroidism
# **************************************************
# Question:
# The technique for accurate quantification of gene expression is
#
# Answer Choices:
# A. Nohern blot
# B. PCR
# C. Real-Time Reverse Transcriptase PCR
# D. Reverse Transcriptase PCR
# **************************************************
# Question:
# A patient presents to the doctor with diplopia when looking towards the right. On examination, he is unable to move his right eye laterally past the midline. Damage to which of these nerves would produce this clinical presentation?
#
# Answer Choices:
# A. Abducent nerve
# B. Trochlear nerve
# C. Optic nerve
# D. Oculomotor nerve
# **************************************************
# Question:
# The arrow marked structure is which part of corpus callosum:
#
# Answer Choices:
# A. Rostrum
# B. Genu
# C. Body
# D. Splenium
# **************************************************
# Question:
# Cytosolic cytochrome C plays an impoant function in -
#
# Answer Choices:
# A. Apoptosis
# B. Cell necrosis
# C. Electron transpo chain
# D. Cell division
# **************************************************
# Question:
# Trigeminal nerve has how many nucleus?
#
# Answer Choices:
# A. 2
# B. 3
# C. 4
# D. 5
# **************************************************
# Question:
# The deformity of tibia in triple deformity of the knee is?
#
# Answer Choices:
# A. Extension, Posterior subluxation & external rotation
# B. Flexion, posterior subluxation & external rotation
# C. Flexion, posterior subluxation & internal rotation
# D. Extension, Anterior subluxation & internal rotation
# **************************************************
# Question:
# What is the most common site of origin of thrombotic pulmonary emboli?
#
# Answer Choices:
# A. Deep leg veins
# B. Lumen of left ventricle
# C. Lumen of right ventricle
# D. Mesenteric veins
# **************************************************
# Question:
# Which of the following nipple discharge is most probably; physiological:
#
# Answer Choices:
# A. B/L spontaneous discharge
# B. B/L milky discharge with squeezing from multiple ducts
# C. U/L bloody discharge
# D. U/L bloody discharge with squeezing from a single duct
# **************************************************
# Question:
# Hallmark of breast malignancy on mammography?
#
# Answer Choices:
# A. Low density lesion
# B. Smooth margins
# C. Clusters of microcalcification
# D. Popcorn calcification
# **************************************************
# Question:
# Computed Tomography (CT scan) is least accurate for diagnosts of:
#
# Answer Choices:
# A. 1cm size Aneurysm in the Hepatic Aery
# B. 1cm size Lymph node inthe para-aoic region
# C. 1cm size Mass in the tail of pancreas
# D. 1cm size Gall stones
# **************************************************
# Question:
# NO is synthesized by -
#
# Answer Choices:
# A. Uracil
# B. Aspartate
# C. Guanosine
# D. Arginine
# **************************************************
# Question:
# The serum concentration of which of the following human Ig is maximum:
#
# Answer Choices:
# A. IgG
# B. IgA
# C. IgM
# D. IgD
# **************************************************
# Question:
# Arlts line is seen in
#
# Answer Choices:
# A. Vernal keratoconjunctis
# B. Pterygium
# C. Ocular pemphigoid
# D. Trachoma
# **************************************************

# %%
compiled_df
# Out:
#       dataset_name  id_in_dataset  \
# 0          medmcqa           7131
# 1          medmcqa           7133
# 2          medmcqa           7134
# 3          medmcqa           7137
# 4          medmcqa           7138
# ...            ...            ...
# 15637         MMLU            995
# 15638         MMLU            996
# 15639         MMLU            997
# 15640         MMLU            998
# 15641         MMLU            999
#
#                                                 question  \
# 0      Urogenital Diaphragm is made up of the followi...
# 1      Child with Type I Diabetes. What is the advise...
# 2                   Most sensitive test for H pylori is-
# 3      Ligation of the common hepatic aery will compr...
# 4            Typhoid investigation of choice in 1st week
# ...                                                  ...
# 15637  You are visiting an 86-year-old woman in her h...
# 15638  A 37-year-old woman comes to the physician bec...
# 15639  A 42-year-old woman is brought to the emergenc...
# 15640  A 19-year-old woman who is a regular patient c...
# 15641  A 44-year-old female presents to the office fo...
#
#                                                  options answer_label  \
# 0      Answer Choices:\nA. Deep transverse Perineus\n...            C
# 1      Answer Choices:\nA. After 5 years\nB. After 2 ...            A
# 2      Answer Choices:\nA. Fecal antigen test\nB. Bio...            B
# 3      Answer Choices:\nA. Right and Left gastric aer...            D
# 4      Answer Choices:\nA. Blood culture\nB. Widal te...            A
# ...                                                  ...          ...
# 15637  Answer Choices:\nA. Admit the patient to the h...            B
# 15638  Answer Choices:\nA. Haemophilus influenzae typ...            D
# 15639  Answer Choices:\nA. CT scan of the abdomen\nB....            D
# 15640  Answer Choices:\nA. Androgen-producing ovarian...            D
# 15641  Answer Choices:\nA. a nuclear thyroid scan\nB....            D
#
#       question_type                                        prompt_text
# 0               MCQ  Question:\nUrogenital Diaphragm is made up of ...
# 1               MCQ  Question:\nChild with Type I Diabetes. What is...
# 2               MCQ  Question:\nMost sensitive test for H pylori is...
# 3               MCQ  Question:\nLigation of the common hepatic aery...
# 4               MCQ  Question:\nTyphoid investigation of choice in ...
# ...             ...                                                ...
# 15637           MCQ  Question:\nYou are visiting an 86-year-old wom...
# 15638           MCQ  Question:\nA 37-year-old woman comes to the ph...
# 15639           MCQ  Question:\nA 42-year-old woman is brought to t...
# 15640           MCQ  Question:\nA 19-year-old woman who is a regula...
# 15641           MCQ  Question:\nA 44-year-old female presents to th...
#
# [15642 rows x 7 columns]

# %%
# view total question count
len(compiled_df)
# Out:
# 15642

# %%
# view question type counts
compiled_df['question_type'].value_counts()
# Out:
# question_type
# MCQ    15040
# Y/N      602
# Name: count, dtype: int64

# %%
# export compiled_df as parquet
compiled_df.to_parquet("compiled_df.parquet")

# %%
# split df based on question type
mcq_df = compiled_df[compiled_df['question_type'] == 'MCQ']
yn_df = compiled_df[compiled_df['question_type'] == 'Y/N']

# export as parquet
mcq_df.to_parquet("mcq_df.parquet")
yn_df.to_parquet("yn_df.parquet")
